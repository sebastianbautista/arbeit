# %% [markdown]
# # Lending Club Description Topic Modeling
#
# In this notebook, I perform topic modeling on the 'desc' field for Lending Club loans categorized as 'other'.
#
# Topic modeling is used to discover abstract "topics" that occur in a collection of documents. The topics produced are clusters of similar words.
#
# I use two techniques, Nonnegative Matrix Factorization (NMF) and Latent Dirichlet Allocation (LDA), and two input matrices, one of the raw counts of the n-grams and one weighted by term frequency-inverse document frequency (tf-idf), for a total of four iterations.

# %%
# %%time
import time
import numpy as np
import pandas as pd
start_time = time.perf_counter()
# Out:
# Wall time: 920 ms

# %% [markdown]
# ### 0. Data Load

# %%
# %%time
# Read in csv containing 'other' loans with populated 'desc' fields
df = pd.read_csv('data/other_loans.csv', header=0, low_memory=False)
print('There are {} observations and {} variables in this dataset.'.format(*df.shape))

# Pull out descriptions
descriptions = df.loc[:, 'desc']
# Out:
# There are 7063 observations and 152 variables in this dataset.
# Wall time: 457 ms

# %% [markdown]
# ### 1. Text Analysis
#
# Now that we have the observations we're interested in, we can extract features.
#
# We begin by using CountVectorizer to count word n-grams of size 1 to 5.
#
# An example of an n-gram of size 1 would be "consolidation" while an n-gram of size 4 would be "credit card debt consolidation". The words must be contiguous in the text.
#
# CountVectorizer converts a collection of text documents to a matrix of token counts.
# Here, each document is a user-provided loan description.
#
# TfIdfTransformer converts a count matrix to a normalized tf-idf (term frequency-inverse document frequency) representation.
# Explanation in a later cell.

# %%
# %%time
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# Our features are word n-grams
analyzer = 'word'

# Create list of stop words
stop_nums = [str(i) for i in list(range(0, 101))]
stop_chars = [
    'br', 'added', 'borrower', 'pay',
    '000', '00', '01', '02', '03', '04', '05',
    '06', '07', '08', '09', '200', '2000',
    'to', 'on', 'and', 'the', 'my', 'for',
    'have', 'of', 'in', 'this', 'is', 'will',
    'off', 'with', 'be', 'am', 'that', 'it',
    'need', 'as', 'some', 'you', 'me', 'we',
    'would', 'been', 'at', 'so', 'very',
    'thank', 'you', 'an', 'get', 'all', 'are',
    'from', 'like', 'our', 'help', 'but', 'if',
    'not', 'was', 'has', 'just', 'do', 'up',
    'over', 'by', 'any', 'right', 'now',
    'month', 'year', 'xc2', 'x80', 'xc3', 'xa2'
]
stop_words = stop_chars + stop_nums

# Upper and lower bound of the range of n-values for n-grams to be extracted
ngram_range = (1, 5)

# Only interested in the 100000 most frequent n-grams
max_features = 100000

# Regex pattern. Currently not working or used
token_pattern = '^([a-zA-Z]+|\d+|\W)$' # TODO: fix this

# Initialize and fit CountVectorizer
cv = CountVectorizer(analyzer=analyzer, stop_words=stop_words,
                    ngram_range=ngram_range, max_features=max_features)
cv_fit = cv.fit_transform(descriptions)

# Convert sparse matrix of n-gram counts to array - this is our raw input
X_raw = cv_fit.toarray()

# Transform our array of n-gram counts to tf-idf weighted
transformer = TfidfTransformer()
X_tfidf = transformer.fit_transform(X_raw)
# Out:
# Wall time: 12.3 s

# %% [markdown]
# ### 2. Non-Negative Matrix Factorization (NMF)
#
# From docs: "Find two non-negative matrices (W, H) whose product approximates the non-negative matrix X. This factorization can be used for example for dimensionality reduction, source separation or topic extraction."
#
# We're interested in topic extraction for topic modeling.

# %%
# %%time
# Define a function for putting our topic modeling output into a readable format
def get_topics(model, num_topics=5):
    """ 
    Pulls out the 30 largest values for each topic, maps
    them to their respective topics in a dictionary, and 
    returns a DataFrame.
    """
    # Get feature names for mapping
    feat_names = cv.get_feature_names()
    word_dict = {}
    # For each topic, get the 30 largest values
    for i in range(num_topics):        
        words_ids = model.components_[i].argsort()[:-30 - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words
    return pd.DataFrame(word_dict)
# Out:
# Wall time: 0 ns

# %% [markdown]
# ### 2a. Plain NMF
#
# First, I use the raw counts matrix from CountVectorizer as an input for the NMF model.

# %%
# %%time
from sklearn.decomposition import NMF

# Number of topics
n_components = 5

# Instantiate NMF model
nmf_model = NMF(n_components=n_components)

# Fit model
nmf_model.fit(X_raw)
# Out:
# Wall time: 2min 23s

# %%
nmf_topics = get_topics(nmf_model)
nmf_topics
# Out:
#        Topic # 01        Topic # 02 Topic # 03  \
# 0            loan            credit       time
# 1         payment             cards      years
# 2        personal      credit cards        job
# 3         lending              card      money
# 4             car       credit card        can
# 5        interest              debt       good
# 6            club          interest      bills
# 7         monthly              high       also
# 8        expenses           payment       work
# 9    lending club               one   business
# 10           used       consolidate       plan
# 11           rate  credit card debt       more
# 12  personal loan         card debt       make
# 13         paying            paying       back
# 14           your              rate   payments
# 15           paid     high interest        had
# 16        current             bills     stable
# 17      loan used              want        out
# 18           home     interest rate    monthly
# 19           debt          payments     income
# 20          which               car    because
# 21         thanks              home       home
# 22         amount             score    company
# 23       payments   interest credit      which
# 24          lower             never        use
# 25        student      credit score   expenses
# 26           than               use       your
# 27           more           monthly         no
# 28           high             rates      about
# 29  interest rate     consolidation        new
#
#                                Topic # 04         Topic # 05
# 0                                   bills                per
# 1                                    paid           mortgage
# 2                                    loan               loan
# 3                               loan paid             credit
# 4                              paid bills             income
# 5                                economic           interest
# 6                                hardship            payment
# 7                       economic hardship               card
# 8                                  facing        credit card
# 9                         loan paid bills              about
# 10                        hardship facing                500
# 11               economic hardship facing               bank
# 12          economic hardship facing loan               rate
# 13     economic hardship facing loan paid      interest rate
# 14                 facing loan paid bills            balance
# 15                       facing loan paid                new
# 16        hardship facing loan paid bills              going
# 17              hardship facing loan paid           security
# 18                   hardship facing loan   mortgage payment
# 19                            facing loan            college
# 20                                 little             social
# 21                           bills little                450
# 22             paid bills little economic    social security
# 23                      paid bills little          community
# 24    paid bills little economic hardship             closed
# 25        loan paid bills little economic               2010
# 26                 loan paid bills little                boa
# 27  bills little economic hardship facing  community college
# 28         bills little economic hardship     per x94balance
# 29                        little economic           onondaga

# %% [markdown]
# Topic #1 seems to be related to **personal loans**. Some n-grams in the topic suggest student or car loans.
#
# Topic #2 is clearly related to **credit card debt**. High interest rates are also mentioned.
#
# Topic #3 is less clear, but looks like it may be related to **small businesses**. Business, expenses, and company are mentioned.
#
# Topic #4 shows that there are a lot of larger n-grams related to **economic hardship** and paying bills. Notably, it has the largest n-grams and seems to be the most focused topic.
#
# Topic #5 is also not very clear, but it looks to be somewhat related to **mortgages**. The mentions of social security, credit card, and community college fall outside of that scope, though. It is also the only topic containing numbers.
#
# Next, I do NMF again but with TfIdf-transformed counts.

# %% [markdown]
# ### 2b. NMF with TfIdf
#
# Tf-Idf stands for term frequency-inverse document frequency. It is used to weight a word's importance.
#
# >The goal of using tf-idf instead of the raw frequencies of occurrence of a token in a given document is to scale down the impact of tokens that occur very frequently in a given corpus and that are hence empirically less informative than features that occur in a small fraction of the training corpus.
#
# "Typically, the tf-idf weight is composed by two terms: the first computes the normalized Term Frequency (TF), aka. the number of times a word appears in a document, divided by the total number of words in that document; the second term is the Inverse Document Frequency (IDF), computed as the logarithm of the number of the documents in the corpus divided by the number of documents where the specific term appears.
#
# TF: Term Frequency, which measures how frequently a term occurs in a document. Since every document is different in length, it is possible that a term would appear much more times in long documents than shorter ones. Thus, the term frequency is often divided by the document length (aka. the total number of terms in the document) as a way of normalization:
#
# TF(t) = (Number of times term t appears in a document) / (Total number of terms in the document).
#
# IDF: Inverse Document Frequency, which measures how important a term is. While computing TF, all terms are considered equally important. However it is known that certain terms, such as "is", "of", and "that", may appear a lot of times but have little importance. Thus we need to weigh down the frequent terms while scale up the rare ones, by computing the following:
#
# IDF(t) = log_e(Total number of documents / Number of documents with term t in it).
#
# See below for a simple example.
#
# Example:
#
# Consider a document containing 100 words wherein the word cat appears 3 times. The term frequency (i.e., tf) for cat is then (3 / 100) = 0.03. Now, assume we have 10 million documents and the word cat appears in one thousand of these. Then, the inverse document frequency (i.e., idf) is calculated as log(10,000,000 / 1,000) = 4. Thus, the Tf-idf weight is the product of these quantities: 0.03 * 4 = 0.12."

# %%
# %%time

# Number of topics
n_components = 5

# Instantiate NMF model
nmf_tfidf = NMF(n_components=n_components)

# Fit model
nmf_tfidf.fit(X_tfidf)
# Out:
# Wall time: 1.75 s

# %%
# Get topics
nmf_tfidf_topics = get_topics(nmf_tfidf)
nmf_tfidf_topics
# Out:
#                     Topic # 01                   Topic # 02  \
# 0                        cards                     personal
# 1                 credit cards                personal loan
# 2                       credit                         loan
# 3                     interest                 personal use
# 4                high interest                          use
# 5                         high                loan personal
# 6              interest credit            personal personal
# 7         high interest credit            personal expenses
# 8        interest credit cards               personal debts
# 9   high interest credit cards            loan personal use
# 10    consolidate credit cards               personal bills
# 11          consolidate credit                personal debt
# 12                        card           loan personal loan
# 13                 credit card               cards personal
# 14               paying credit        credit cards personal
# 15         paying credit cards                        debts
# 16                      paying           personal loan debt
# 17                 consolidate          personal loan bills
# 18           loan credit cards                     expenses
# 19                 loan credit       personal loan personal
# 20                      payoff  personal loan personal loan
# 21               payoff credit                   loan bills
# 22                 want credit                    loan debt
# 23           want credit cards                     purposes
# 24                bills credit            personal purposes
# 25         payoff credit cards         personal loan credit
# 26          bills credit cards              personal family
# 27                        want                personal trip
# 28       credit cards personal   credit cards personal loan
# 29              cards personal          cards personal loan
#
#                              Topic # 03                  Topic # 04  \
# 0                         consolidation                       bills
# 1                    debt consolidation               medical bills
# 2                                  debt                     medical
# 3                    bill consolidation                 consolidate
# 4                      consolidate debt           consolidate bills
# 5                           consolidate                 bills bills
# 6                    consolidation debt                paying bills
# 7                    consolidation loan                  loan bills
# 8                                  bill                      paying
# 9               debt consolidation loan                  card bills
# 10                     credit card debt           credit card bills
# 11                            card debt                bills credit
# 12                            loan debt                   few bills
# 13                   consolidation home                       catch
# 14                   loan consolidation                         few
# 15              debt consolidation home                  bills time
# 16              loan debt consolidation                    vacation
# 17     consolidation debt consolidation              personal bills
# 18              card debt consolidation                 catch bills
# 19       credit card debt consolidation                       other
# 20       consolidation home improvement                   bills one
# 21                   card consolidation                  want bills
# 22            credit card consolidation          bills credit cards
# 23              debt consolidation debt                        time
# 24  debt consolidation home improvement                 small bills
# 25                                 home                 other bills
# 26                        personal debt         cards medical bills
# 27                          credit card                       small
# 28                 consolidation credit               cards medical
# 29           wedding debt consolidation  credit cards medical bills
#
#           Topic # 05
# 0               loan
# 1               card
# 2        credit card
# 3                car
# 4               home
# 5             credit
# 6            repairs
# 7           expenses
# 8               debt
# 9              years
# 10              time
# 11               job
# 12           payment
# 13             money
# 14       consolidate
# 15             taxes
# 16              used
# 17               new
# 18          interest
# 19               one
# 20           monthly
# 21       improvement
# 22  credit card debt
# 23         card debt
# 24          payments
# 25               use
# 26  home improvement
# 27               can
# 28              good
# 29              work

# %% [markdown]
# These topics look more focused compared to using the non-TfIdf data.
#
# There is overlap between topics (credit card vs cards, consolidate vs consolidation) that can be fixed by proper stemming and/or lemmatization.
#
# It looks like credit cards are mentioned in every topic so hopefully this can be fixed by stemming.
#
# Topic #1 is clearly related to **high interest credit cards** and consolidation.
#
# Topic #2 is related to **personal loans** but credit cards also make it in there. Personal family and personal trip hint at vacation related expenses.
#
# Topic #3 is about **debt consolidation** with mentions of credit card debt, home improvement and wedding debt.
#
# Topic #4 is about **bills**, specifically medical bills. Credit cards and vacation are also mentioned.
#
# Topic #5 is less focused than the rest, but some terms that stand out are **car, home, repairs, and improvement**.
#
# Next, I use Latent Dirichlet Allocation (LDA) for topic modeling.

# %% [markdown]
# ### 3. Latent Dirichlet Allocation (LDA)
#
# From docs: "Latent Dirichlet Allocation with online variational Bayes algorithm."
#
# This process is random so it's somewhat less reliable than NMF, but `random_state` can be set for reproducibility.

# %% [markdown]
# ### 3a. Plain LDA
#
# First, I use the raw counts matrix from CountVectorizer as an input for the LDA model.

# %%
# %%time
from sklearn.decomposition import LatentDirichletAllocation as LDA

# Number of topics
n_components = 5

# Use all available cores
n_jobs = -1

# Instantiate LatentDirichletAllocation model
lda_model = LDA(n_components=n_components, n_jobs=n_jobs, verbose=1, random_state=0)

# Fit model
lda_model.fit(X_raw)
# Out:
# c:\econsw\python36\lib\site-packages\sklearn\decomposition\online_lda.py:536: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# Wall time: 4min 17s

# %%
lda_topics = get_topics(lda_model)
lda_topics
# Out:
#                    Topic # 01          Topic # 02   Topic # 03  \
# 0                       taxes                 car         loan
# 1                        loan             repairs       credit
# 2                    property                home         time
# 3                        your       consolidation        years
# 4                         irs                loan          job
# 5                        what              repair         debt
# 6                     federal                debt      payment
# 7                          im  debt consolidation        bills
# 8                   your loan                 new      monthly
# 9                        real            vacation         good
# 10                       tell             vehicle     payments
# 11                       boat            purchase     expenses
# 12                   purchase               bills          use
# 13                      story         improvement          one
# 14                       land                 fix        money
# 15                 short term                take          can
# 16                real estate    home improvement       stable
# 17                    planing                work         home
# 18                      legal            personal         plan
# 19                     market         car repairs         used
# 20            story what your                care         card
# 21            tell your story           take care         paid
# 22                 your story               needs        funds
# 23             what your loan               house  credit card
# 24  your story what your loan               money         also
# 25  tell your story what your                auto       paying
# 26       story what your loan        home repairs        which
# 27       your story what your               small         more
# 28       tell your story what          motorcycle         make
# 29            your story what               truck         than
#
#                Topic # 04     Topic # 05
# 0                  credit       business
# 1                   cards           loan
# 2            credit cards          money
# 3                interest       personal
# 4                    loan            her
# 5                   bills         family
# 6                    card           home
# 7             credit card            she
# 8                    high           wife
# 9                    rate            his
# 10                medical  personal loan
# 11          interest rate       expenses
# 12          high interest             he
# 13                 paying            who
# 14          medical bills            son
# 15                 higher        medical
# 16        interest credit           work
# 17                 payoff      use money
# 18                  lower          start
# 19            consolidate       purchase
# 20                  other            new
# 21                   want            out
# 22        higher interest            can
# 23                  loans           back
# 24         lower interest          small
# 25   high interest credit          needs
# 26  interest credit cards             us
# 27                   debt       daughter
# 28                  rates          costs
# 29                   bill            him

# %% [markdown]
# Results don't seem as good as with NMF.
#
# Topic #1: **Taxes?** Weird results with "tell your story what your loan"
#
# Topic #2: All over the place with car repairs, debt consolidation, and home improvement. **Personal loans?**
#
# Topic #3: Vaguely about **credit cards** but with a positive spin - good, stable, etc.
#
# Topic #4: **High interest credit cards** with a few mentions of medical bills.
#
# Topic #5: **Business** is the top term but there are a lot of connected terms like family, wife, son and daughter. Also mentions personal loans and medical.
#
# Overall not as useful. Let's see what happens when we use the Tf-Idf weighted inputs.

# %% [markdown]
# ### 3b. LDA with TfIdf

# %%
# %%time
# Number of topics
n_components = 5

# Use all available cores
n_jobs = -1

# Instantiate LatentDirichletAllocation model
lda_tfidf = LDA(n_components=n_components, n_jobs=n_jobs, verbose=1, random_state=0)

# Fit model
lda_tfidf.fit(X_tfidf)
# Out:
# c:\econsw\python36\lib\site-packages\sklearn\decomposition\online_lda.py:536: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# Wall time: 2min 27s

# %%
lda_tfidf_topics = get_topics(lda_tfidf)
lda_tfidf_topics
# Out:
#                   Topic # 01          Topic # 02  \
# 0                      taxes                loan
# 1                state taxes               bills
# 2             property taxes            personal
# 3                 back taxes                debt
# 4                      state              credit
# 5                    federal                 car
# 6                   property       consolidation
# 7              federal state            expenses
# 8        federal state taxes               years
# 9              federal taxes                time
# 10                2012 taxes                 job
# 11               taxes taxes             payment
# 12                taxes home               money
# 13       loan property taxes       personal loan
# 14       property taxes home             repairs
# 15             loan property         consolidate
# 16                 taxes irs                home
# 17                  owe back             medical
# 18            owe back taxes  debt consolidation
# 19  loan property taxes home               cards
# 20         taxes consolidate                 use
# 21                      test                 one
# 22                    pickup        credit cards
# 23             state federal                card
# 24           paying attorney             monthly
# 25      paying attorney fees               other
# 26          legal assistance             wedding
# 27                  perspnal              paying
# 28         paying back taxes         credit card
# 29             taxes federal                 can
#
#                               Topic # 03                          Topic # 04  \
# 0                                camping                 cards medical bills
# 1                     camping membership          credit cards medical bills
# 2                             membership                       cards medical
# 3                                     dr                credit cards medical
# 4                       home renovations                             wedding
# 5                         purchase bills                   daughters wedding
# 6                               occasion                           honeymoon
# 7                use personal use stable                         consolation
# 8          cut expenses creditcard rates                             planing
# 9            use personal use stable job            wedding expenses wedding
# 10                       loan assist cut                           daughters
# 11            than 15yrs experience same                        loan wedding
# 12        assist cut expenses creditcard                        wedding loan
# 13          experience same company loan                          im planing
# 14   experience same company loan assist               loan wedding expenses
# 15                            assist cut                   wedding honeymoon
# 16         15yrs experience same company                         medications
# 17  assist cut expenses creditcard rates                   medications bills
# 18                            than 15yrs                personal loan family
# 19                       more than 15yrs                  ceremony reception
# 20                 15yrs experience same                 family member needs
# 21             expenses creditcard rates                        member needs
# 22        job more than 15yrs experience                     loan im planing
# 23              use stable job more than                  hardworking person
# 24                      15yrs experience                   time cosideration
# 25            stable job more than 15yrs       money im planing soon posible
# 26                   use stable job more                         posible had
# 27      personal use personal use stable                      im hardworking
# 28                      creditcard rates         position im what makes good
# 29               company loan assist cut  self family your time cosideration
#
#                Topic # 05
# 0                  credit
# 1                   cards
# 2            credit cards
# 3                    home
# 4                    card
# 5                interest
# 6             credit card
# 7             improvement
# 8        home improvement
# 9                    high
# 10                   loan
# 11          high interest
# 12               vacation
# 13                   rate
# 14        interest credit
# 15           improvements
# 16            consolidate
# 17          interest rate
# 18                 payoff
# 19                   debt
# 20      home improvements
# 21   high interest credit
# 22                 family
# 23                  bills
# 24  interest credit cards
# 25                    new
# 26                 higher
# 27               purchase
# 28                   used
# 29               business

# %% [markdown]
# We get much longer n-grams here because of the inverse document frequency portion of Tf-Idf.
#
# Topic #1: Dominated by **taxes** (state, federal, property, back) with some mentions of **paying attorney fees**
#
# Topic #2: Not as focused, but looks like **credit cards** and **debt consolidation**. Also mentions wedding, personal loan, medical, and repairs.
#
# Topic #3: **Camping** is at the top of the list, which is strange. The rest of the list shows that the topic is about having a stable job and more than 15 years experience. Not very useful.
#
# Topic #4: **Credit cards, medical bills, and wedding expenses** dominate this topic.
#
# Topic #5: Looks similar to topic #2 because of the mentions of **high interest credit cards** but also has terms that hint at **home improvement**
#
# These results are also not that great. Credit cards make an appearance in 3/5 of the topics, and a lot of the longer n-grams seem irrelevant but are weighted relatively heavily because of their low document frequency.

# %% [markdown]
# TODO:
# * Understand regex in order to come up with a custom token_pattern
# * Stemming and lemmatization?
#   * See https://rstudio-pubs-static.s3.amazonaws.com/79360_850b2a69980c4488b1db95987a24867a.html

# %%
end_time = (time.perf_counter() - start_time)/60
print("This notebook took {:0.2f} minutes to run".format(end_time))
# Out:
# This notebook took 9.41 minutes to run
